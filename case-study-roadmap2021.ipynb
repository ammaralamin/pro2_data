# %%
# This R environment comes with many helpful analytics packages installed
# It is defined by the kaggle/rstats Docker image: https://github.com/kaggle/docker-rstats
# For example, here's a helpful package to load

library(tidyverse) # metapackage of all tidyverse packages

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

list.files(path = "../input")

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
library(tidyverse)
library(readr)
library(ggplot2)
library(lubridate)

# %% [markdown]
# **Importing Data**

# %%
df_cycclist_data1 <- read_csv("../input/cyclistic-data-2021/202101-divvy-tripdata.csv")
df_cycclist_data2 <- read_csv("../input/cyclistic-data-2021/202102-divvy-tripdata.csv")
df_cycclist_data3 <- read_csv("../input/cyclistic-data-2021/202103-divvy-tripdata.csv")
df_cycclist_data4 <- read_csv("../input/cyclistic-data-2021/202104-divvy-tripdata.csv")
df_cycclist_data5 <- read_csv("../input/cyclistic-data-2021/202105-divvy-tripdata.csv")
df_cycclist_data6 <- read_csv("../input/cyclistic-data-2021/202106-divvy-tripdata.csv")
df_cycclist_data7 <- read_csv("../input/cyclistic-data-2021/202107-divvy-tripdata.csv")
df_cycclist_data8 <- read_csv("../input/cyclistic-data-2021/202108-divvy-tripdata.csv")
df_cycclist_data9 <- read_csv("../input/cyclistic-data-2021/202109-divvy-tripdata.csv")
df_cycclist_data10 <- read_csv("../input/cyclistic-data-2021/202110-divvy-tripdata.csv")
df_cycclist_data11 <- read_csv("../input/cyclistic-data-2021/202111-divvy-tripdata.csv")
df_cycclist_data12 <- read_csv("../input/cyclistic-data-2021/202112-divvy-tripdata.csv")

# %% [markdown]
# Preper the column for Merging

# %%
glimpse(df_cycclist_data1)
glimpse(df_cycclist_data2)
glimpse(df_cycclist_data3)
glimpse(df_cycclist_data4)
glimpse(df_cycclist_data5)
glimpse(df_cycclist_data6)
glimpse(df_cycclist_data7)
glimpse(df_cycclist_data8)
glimpse(df_cycclist_data9)
glimpse(df_cycclist_data10)
glimpse(df_cycclist_data11)
glimpse(df_cycclist_data12)

# %% [markdown]
# Prepper the columns to be the same unite

# %%
df_cycclist_data1 <- mutate(df_cycclist_data1, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data2 <- mutate(df_cycclist_data2, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data3 <- mutate(df_cycclist_data3, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data4 <- mutate(df_cycclist_data4, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data5 <- mutate(df_cycclist_data5, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data6 <- mutate(df_cycclist_data6, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data7 <- mutate(df_cycclist_data7, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data8 <- mutate(df_cycclist_data8, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data9 <- mutate(df_cycclist_data9, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data10 <- mutate(df_cycclist_data10, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data11 <- mutate(df_cycclist_data11, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))
df_cycclist_data12 <- mutate(df_cycclist_data12, started_at = 
                        as.character(started_at),
                      ended_at = as.character(ended_at))

# %% [markdown]
# Merging the data in one Table

# %%
cyclistic2021.df <- bind_rows(df_cycclist_data1, df_cycclist_data2,   df_cycclist_data3,
                              df_cycclist_data4 ,df_cycclist_data5 ,df_cycclist_data6,
                              df_cycclist_data7,  df_cycclist_data8,  df_cycclist_data9,
                              df_cycclist_data10, df_cycclist_data11, df_cycclist_data12)

# %% [markdown]
# Show the table

# %%
dim(cyclistic2021.df) 
head(cyclistic2021.df, 10) 
colnames(cyclistic2021.df) 
glimpse(cyclistic2021.df)

# %%
View(cyclistic2021.df)

# %% [markdown]
#  Check if there any duplicate

# %%
unique(cyclistic2021.df$rideable_type)
unique(cyclistic2021.df$member_casual)

# %%
cyclistic2021.df[duplicated( cyclistic2021.df$ride_id), ]

# %% [markdown]
# Checking for negative time

# %%
cyclistic2021.df %>% 
  filter(ended_at < started_at) %>% 
  count()

# %% [markdown]
# Removing negative time

# %%
cyclistic2021.df <- cyclistic2021.df %>% 
  filter(ended_at > started_at)

glimpse(cyclistic2021.df)

# %% [markdown]
# Removing rows with na values

# %%
cyclistic2021.df <- cyclistic2021.df %>% 
  na.omit()

# %% [markdown]
# Renaming Varibles

# %%
 

glimpse(cyclistic2021.df)

# %% [markdown]
#   **Changing started_at and ended_at type to datetime**
# *We need to change the columns containing datetime values from chr to datatime type in order to work with it*

# %%
 cyclistic2021.df<- cyclistic2021.df %>%
  mutate(started_at = ymd_hms(started_at),
         ended_at = ymd_hms(ended_at))

# %% [markdown]
# Extracting the days from the started_at variable

# %%
 cyclistic2021.df <-  cyclistic2021.df %>% 
  mutate(weekday = wday(started_at, label=TRUE, abbr=TRUE))

# %% [markdown]
# Extracting months from started_at variable

# %%
 cyclistic2021.df <-  cyclistic2021.df %>% 
  mutate(month = month(started_at, label=TRUE, abbr=TRUE))

# %% [markdown]
# **Extracting the years from the started_at variable**

# %%
cyclistic2021.df <- cyclistic2021.df %>% 
  mutate(year = year(started_at))

# %% [markdown]
# **Extracting the time from the started_at and ended_at as a variable**

# %%
cyclistic2021.df <- cyclistic2021.df %>% 
  mutate(start_time = format(started_at, "%H:%M:%S")) %>% 
  mutate(end_time = format(ended_at, "%H:%M:%S")) %>% 
  # converting the time variable the the approriate datatype
  mutate(start_time = hms(start_time)) %>% 
  mutate(end_time = hms(end_time))

# %% [markdown]
# Extracting the hour from the timestamp as a variable

# %%
cyclistic2021.df <- cyclistic2021.df %>% 
  mutate(hour = hour(start_time))

# %% [markdown]
# **Creating a duration variable**

# %%
cyclistic2021.df$duration <- difftime(cyclistic2021.df$ended_at, 
                               cyclistic2021.df$started_at, units = "mins")

head(cyclistic2021.df, 5)

# %% [markdown]
# Analyze Data

# %%
# checking for the count of members and casual riders
table(cyclistic2021.df$rideable_type)
table(cyclistic2021.df$member_casual)

# %%
# visualizing the user count
ggplot(cyclistic2021.df, aes(member_casual, fill = member_casual)) +
  geom_bar() +
labs(title = 'User type Count',
    x = 'User Type',
    y = 'Count')
 


# plotting a graph to better visualize the result
cyclistic2021.df %>%
ggplot(aes(x = rideable_type, fill =rideable_type)) +
  geom_bar() +
  facet_wrap(~member_casual) +
  labs(title = 'Count of Casual and Members Riders', 
       x = 'Ride Type',
       y = 'Count')

# %%
# day of the weeks

cyclistic2021.df %>%
 ggplot(aes(x=weekday,fill = rideable_type)) +
  geom_bar() +
  labs(title = 'The week day', 
       x = 'Weekday',
       y = 'Count')

# %%
head(cyclistic2021.df )

# %%
data2021_1.df <- cyclistic2021.df

# %%
#save out our file
write_csv(data2021_1.df,"data2021-1.csv")
